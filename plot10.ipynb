# %% [markdown]
# # heading

# %% [markdown]
# ## level 2 heading
# text here

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(range(10))

# %%
plt.plot(np.sin(range(10)))
